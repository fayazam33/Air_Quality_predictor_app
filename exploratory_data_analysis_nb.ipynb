# %%
import matplotlib.pyplot as plt
import seaborn as sns 
import pandas as pd
df = pd.read_csv(r"F:\Machine Learning\Project-02\Data\air_quality_data.csv")
df
# Out:
#           PM2.5        PM10        NO2        CO  Temperature   Humidity  \
# 0     74.908024   55.539879  26.170568  6.727030    18.599794  39.363552
# 1    190.142861  162.570284  24.697880  7.966814    30.271616  47.343566
# 2    146.398788  261.883751  90.625458  2.504679    28.008046  85.454739
# 3    119.731697  219.667466  24.954620  6.248741    -2.305005  34.000439
# 4     31.203728  241.968344  27.194973  5.717460    -2.537527  86.964968
# ..          ...         ...        ...       ...          ...        ...
# 995   18.316415  197.086547  86.529576  4.421070    34.869866  68.443536
# 996  183.462715  286.984386  15.727321  3.344012    -4.030949  50.322041
# 997   27.363726   20.687405  30.978786  3.945723     6.392142  76.514885
# 998  190.047471   17.116416  29.004553  5.299406    30.787269  48.529063
# 999   89.201155   84.656122  87.141403  1.613674    19.865619  14.938164
#
#             AQI  Safe
# 0    194.477086     0
# 1     51.715909     1
# 2    261.718369     0
# 3    183.934872     0
# 4     47.161165     1
# ..          ...   ...
# 995  173.921134     0
# 996  200.111057     0
# 997  273.473066     0
# 998  103.686051     0
# 999  186.452193     0
#
# [1000 rows x 8 columns]

# %%
X = df[['PM2.5' , 'PM10' , 'NO2' , 'CO' , 'Temperature', 'Humidity' ]]
y_reg = df['AQI']
y_class = df['Safe']

# %%
plt.figure(figsize=(8 , 6))
sns.scatterplot(x= X['PM2.5'] , y = X['NO2'] , hue = y_class )
plt.title('K-means Clustering')
# Out:
# Text(0.5, 1.0, 'K-means Clustering')
